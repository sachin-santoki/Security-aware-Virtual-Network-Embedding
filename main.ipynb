# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Here you have to set your location where all python file present
# %cd /content/drive/MyDrive/cloud project/cloud_alib
# Out:
# /content/drive/MyDrive/cloud project/cloud_alib

# %%
# !pip install gurobipy
# !pip install Unidecode
# Out:
# ...
#      |████████████████████████████████| 11.5 MB 14.6 MB/s
# ...
#      |████████████████████████████████| 235 kB 14.9 MB/s
# ...

# %%
# !unzip alib
# Out:
# Archive:  alib.zip
# replace alib/cli.md? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %env ALIB_EXPERIMENT_HOME=cloud_alib
# Out:
# env: ALIB_EXPERIMENT_HOME=cloud_alib

# %%
##if you want to read any pickle file than you can use this cell
# !python -m alib.cli  pretty-print  input/graph.pickle
# Out:
#  substrate:
#  graph.Graph @ 0x7f7e25d2d190
#   edge_weights:
#    ('5', '4'): 133
#    ('4', '5'): 133
#    ('0', '1'): 118
#    ('1', '0'): 118
#    ('4', '3'): 136
#    ('3', '4'): 136
#    ('2', '6'): 113
#    ('6', '2'): 113
#    ('5', '2'): 197
#    ('2', '5'): 197
#    ('1', '3'): 258
#    ('3', '1'): 258
#   edges:
#    [('5', '4'), ('4', '5'), ('0', '1'), ('1', '0'), ('4', '3'), ('3', '4'), ('2', '6'), ('6', '2'), ('5', '2'), ('2', '5'), ('1', '3'), ('3', '1')]
#     ('5', '4')
#     ('4', '5')
#     ('0', '1')
#     ('1', '0')
#     ('4', '3')
#     ('3', '4')
#     ('2', '6')
#     ('6', '2')
#     ('5', '2')
#     ('2', '5')
#     ('1', '3')
#     ('3', '1')
#   neighbours:
#    0:
#     {'1'}
#    1:
#     {'0', '3'}
#    2:
#     {'6', '5'}
#    3:
#     {'4', '1'}
#    4:
#     {'3', '5'}
#    5:
#     {'4', '2'}
#    6:
#     {'2'}
#   node_demand:
#    0: 98
#    1: 80
#    2: 55
#    3: 99
#    4: 63
#    5: 94
#    6: 53
#   node_level:
#    0: 106
#    1: 111
# ...

# %%
# !python run.py
# Out:
# ***Physical Substrate Structure***
# Node	 weights 	 demand 	 level
# 0 	 90 	 	 64 		 143
# 1 	 63 	 	 75 		 119
# 2 	 74 	 	 71 		 182
# 3 	 71 	 	 86 		 188
# 4 	 54 	 	 87 		 142
# 5 	 86 	 	 81 		 174
# 6 	 72 	 	 57 		 147
# Edge weights of physical substrate
# ('5', '4')  :  207
# ('4', '5')  :  207
# ('0', '1')  :  263
# ('1', '0')  :  263
# ('4', '3')  :  220
# ('3', '4')  :  220
# ('2', '6')  :  220
# ('6', '2')  :  220
# ('5', '2')  :  202
# ('2', '5')  :  202
# ('1', '3')  :  227
# ('3', '1')  :  227
#
#
# ***Virtual Node request***
# Node	 weights 	 demand 	 level
# 0 	 34 	 	 63 		 118
# 1 	 43 	 	 90 		 145
# 2 	 20 	 	 85 		 110
# Edge weights of virtual reuquest
# ('2', '1')  :  70
# ('1', '2')  :  70
# ('0', '1')  :  96
# ('1', '0')  :  96
#
#
# Implement Topsis on VNR for best order to map
# {2: 0, 1: 1, 3: 2}
#
#
# Implement Topsis on physical Substrate for best order to map
# {1: 0, 6: 1, 2: 2, 5: 3, 4: 4, 7: 5, 3: 6}
#
#
#
# ...
